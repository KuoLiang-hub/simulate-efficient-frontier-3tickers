# %%
# shows sector performance
# see details (https://finance.yahoo.com/screener/predefined/ms_communication_services/?.tsrc=fin-srch)

import pandas as pd
import pandas_datareader.data as web
from matplotlib import pyplot as plt

# %%
# using yahoo finance data
# S&P 500 Telecommunication Services (Sector) (^SP500-50)

# a dictionary of sector and ticker
sector_dictionary = {'^SP500-50':'Telecommunication Services'}

sectors = ['^SP500-50','CMCSA','FB','T','VZ']
sector_data = pd.DataFrame()

for a in sectors:
    #you can chagne the start date to any date in 'yyyy-mm-dd' format.
    sector_data[a] = web.DataReader(a, data_source = 'yahoo', start = '2021-1-1')['Adj Close'] 

sector_data.rename(columns = sector_dictionary, inplace =True)
sector_data.head() #check the beginning of the data
# Out:
#             Telecommunication Services      CMCSA          FB          T  \
# Date
# 2021-01-04                  218.580002  49.095455  268.940002  19.399412
# 2021-01-05                  219.169998  48.802521  270.970001  19.280802
# 2021-01-06                  217.720001  49.368862  263.309998  19.656403
# 2021-01-07                  220.770004  49.466503  268.739990  19.709118
# 2021-01-08                  221.320007  50.325771  267.570007  19.573196
#
#                    VZ
# Date
# 2021-01-04  54.958897
# 2021-01-05  54.706753
# 2021-01-06  55.369804
# 2021-01-07  55.245209
# 2021-01-08  54.556179

# %%
sector_data.tail() #check the end of the data
# Out:
#             Telecommunication Services      CMCSA          FB          T  \
# Date
# 2022-05-11                  193.919998  39.840000  188.740005  19.430000
# 2022-05-12                  194.910004  41.389999  191.240005  19.719999
# 2022-05-13                  199.809998  41.480000  198.619995  19.840000
# 2022-05-16                  198.630005  41.869999  200.039993  20.280001
# 2022-05-17                  201.270004  42.529999  201.480606  20.469999
#
#                    VZ
# Date
# 2022-05-11  47.880001
# 2022-05-12  48.060001
# 2022-05-13  48.180000
# 2022-05-16  49.040001
# 2022-05-17  49.145000

# %%
(sector_data / sector_data.iloc[0]).plot(figsize=(12, 6)) #Plot of company performance without considering dividends
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
(sector_data.iloc[-1] - sector_data.iloc[0]) / sector_data.iloc[0] #shows returns since begining date.
# Out:
# Telecommunication Services   -0.079193
# CMCSA                        -0.133728
# FB                           -0.250834
# T                             0.055187
# VZ                           -0.105786
# dtype: float64
