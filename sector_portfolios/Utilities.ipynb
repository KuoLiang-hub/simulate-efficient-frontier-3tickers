# %%
# shows sector performance
# see details (https://finance.yahoo.com/screener/predefined/ms_utilities/?.tsrc=fin-srch)

import pandas as pd
import pandas_datareader.data as web
from matplotlib import pyplot as plt

# %%
# using yahoo finance data
# S&P 500 Utilities (Sector) (^SP500-55)

# a dictionary of sector and ticker
sector_dictionary = {'^SP500-55':'Utilities'}

sectors = ['^SP500-55','NEE','DUK','SO','AWK']
sector_data = pd.DataFrame()

for a in sectors:
    #you can chagne the start date to any date in 'yyyy-mm-dd' format.
    sector_data[a] = web.DataReader(a, data_source = 'yahoo', start = '2021-1-1')['Adj Close'] 

sector_data.rename(columns = sector_dictionary, inplace =True)
sector_data.head() #check the beginning of the data
# Out:
#              Utilities        NEE        DUK         SO         AWK
# Date
# 2021-01-04  310.760010  72.386574  84.669609  55.865929  146.885223
# 2021-01-05  310.859985  72.922981  84.707359  56.232967  147.716217
# 2021-01-06  318.510010  76.492577  85.802185  57.607033  148.957870
# 2021-01-07  314.269989  77.331329  84.839493  57.541149  148.733017
# 2021-01-08  317.000000  79.125877  84.990509  57.945839  153.474701

# %%
sector_data.tail() #check the end of the data
# Out:
#              Utilities        NEE         DUK         SO         AWK
# Date
# 2022-05-11  361.779999  70.199997  108.925003  73.300919  144.039993
# 2022-05-12  357.600006  68.510002  108.849998  73.400002  145.820007
# 2022-05-13  361.510010  69.800003  109.300003  73.650002  146.479996
# 2022-05-16  362.690002  70.120003  110.029999  74.250000  145.970001
# 2022-05-17  364.459991  71.400002  108.540001  74.099998  146.339996

# %%
(sector_data / sector_data.iloc[0]).plot(figsize=(12, 6)) #Plot of company performance without considering dividends
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
(sector_data.iloc[-1] - sector_data.iloc[0]) / sector_data.iloc[0] #shows returns since begining date.
# Out:
# Utilities    0.172802
# NEE         -0.013629
# DUK          0.281924
# SO           0.326390
# AWK         -0.003712
# dtype: float64
