# %%
# shows sector performance
# see details (https://finance.yahoo.com/screener/predefined/ms_healthcare/?.tsrc=fin-srch)

import pandas as pd
import pandas_datareader.data as web
from matplotlib import pyplot as plt

# %%
# using yahoo finance data
# S&P 500 Health Care (Sector) (^SP500-35)

# a dictionary of sector and ticker
sector_dictionary = {'^SP500-35':'Health Care'}

sectors = ['^SP500-35','JNJ','PFE','ABBV']
sector_data = pd.DataFrame()

for a in sectors:
    #you can chagne the start date to any date in 'yyyy-mm-dd' format.
    sector_data[a] = web.DataReader(a, data_source = 'yahoo', start = '2021-1-1')['Adj Close'] 

sector_data.rename(columns = sector_dictionary, inplace =True)
sector_data.head() #check the beginning of the data
# Out:
#             Health Care         JNJ        PFE        ABBV
# Date
# 2021-01-04  1316.890015  151.679230  34.872280   98.713379
# 2021-01-05  1325.670044  153.462555  35.232269   99.734138
# 2021-01-06  1344.349976  154.906662  34.929119   98.872581
# 2021-01-07  1362.089966  155.430023  35.109116   99.930794
# 2021-01-08  1368.540039  155.110168  35.175434  100.455223

# %%
sector_data.tail() #check the end of the data
# Out:
#             Health Care         JNJ        PFE        ABBV
# Date
# 2022-05-10  1477.689941  177.089996  49.089676  152.089996
# 2022-05-11  1468.219971  176.130005  49.049999  151.960007
# 2022-05-12  1481.800049  177.869995  50.389999  154.289993
# 2022-05-13  1497.400024  176.850006  49.919998  153.500000
# 2022-05-16  1507.750000  178.080002  50.669998  155.470001

# %%
(sector_data / sector_data.iloc[0]).plot(figsize=(12, 6)) #Plot of company performance without considering dividends
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
(sector_data.iloc[-1] - sector_data.iloc[0]) / sector_data.iloc[0] #shows returns since begining date.
# Out:
# Health Care    0.144932
# JNJ            0.174057
# PFE            0.453016
# ABBV           0.574964
# dtype: float64
