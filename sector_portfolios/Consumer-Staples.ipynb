# %%
# shows sector performance
# see details (https://finance.yahoo.com/screener/predefined/ms_consumer_defensive/?.tsrc=fin-srch)
import pandas as pd
import pandas_datareader.data as web
from matplotlib import pyplot as plt

# %%
# using yahoo finance data
# S&P 500 Consumer Staples (Sector) (^SP500-30)

# a dictionary of sector and ticker
sector_dictionary = {'^SP500-30':'Consumer Staples'}

sectors = ['^SP500-30','WMT','COST','TGT','HSY']
sector_data = pd.DataFrame()

for a in sectors:
    #you can chagne the start date to any date in 'yyyy-mm-dd' format.
    sector_data[a] = web.DataReader(a, data_source = 'yahoo', start = '2021-1-1')['Adj Close'] 

sector_data.rename(columns = sector_dictionary, inplace =True)
sector_data.head() #check the beginning of the data
# Out:
#             Consumer Staples         WMT        COST         TGT         HSY
# Date
# 2021-01-04        688.690002  143.160202  376.088348  174.467819  147.243164
# 2021-01-05        688.760010  142.398148  371.725494  177.158997  147.077286
# 2021-01-06        688.299988  143.287201  366.066620  185.556808  147.594452
# 2021-01-07        686.070007  143.277435  363.989044  187.697998  147.506638
# 2021-01-08        689.469971  143.257889  365.987457  190.153503  148.345779

# %%
sector_data.tail() #check the end of the data
# Out:
#             Consumer Staples         WMT        COST         TGT         HSY
# Date
# 2022-05-10        793.969971  149.179993  501.459991  219.110001  223.149994
# 2022-05-11        791.229980  147.619995  489.079987  213.490005  224.630005
# 2022-05-12        790.760010  147.479996  486.179993  217.270004  222.529999
# 2022-05-13        802.000000  148.050003  497.269989  219.729996  225.910004
# 2022-05-16        805.640015  148.210007  494.529999  219.250000  229.320007

# %%
(sector_data / sector_data.iloc[0]).plot(figsize=(12, 6)) #Plot of company performance without considering dividends
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
(sector_data.iloc[-1] - sector_data.iloc[0]) / sector_data.iloc[0] #shows returns since begining date.
# Out:
# Consumer Staples    0.169815
# WMT                 0.035274
# COST                0.314930
# TGT                 0.256679
# HSY                 0.557424
# dtype: float64
