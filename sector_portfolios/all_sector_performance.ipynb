# %%
# shows sector performance
# see details what sector entails (https://www.sofi.com/learn/content/sp-500-sectors/)

import pandas as pd
import pandas_datareader.data as web
from matplotlib import pyplot as plt

# %%
# Forex (https://pandas-datareader.readthedocs.io/en/latest/remote_data.html#remote-data-tiingo)
# Alpha Vantage provides sector performances through the top-level function get_sector_performance_av.

web.get_sector_performance_av(api_key = 'EKA9MJ18TLFQY6SJ').head()
# Out:
#                  RT      1D     5D       1M       3M      YTD       1Y  \
# Energy        2.70%   2.78%  1.19%  -14.56%   -6.50%   33.00%   34.50%
# Utilities    -0.36%   0.81%  8.11%   -5.78%   -4.38%   -2.75%    8.65%
# Financials   -0.93%  -0.44%  4.68%   -7.54%  -18.46%  -17.49%  -12.75%
# Materials    -1.07%  -0.81%  1.85%  -10.84%  -14.92%  -16.18%   -7.48%
# Industrials  -1.15%  -0.25%  3.97%   -5.00%  -14.58%  -16.25%  -13.41%
#
#                  3Y      5Y      10Y
# Energy       19.76%  18.69%   18.02%
# Utilities    17.47%  29.92%   91.82%
# Financials   19.61%  34.49%  181.90%
# Materials    31.62%  40.76%  122.54%
# Industrials  16.25%  28.59%  152.23%

# %%
# using yahoo finance data
# S&P 500 Industrials (Sector) (^SP500-20)
# S&P 500 Information Technology (Sector) (^SP500-45)
# S&P 500 Health Care (Sector) (^SP500-35)
# S&P 500 Financials (Sector) (^SP500-40)
# S&P 500 Real Estate (Sector) (^SP500-60)
# S&P 500 Energy (Sector) (^GSPE)
# S&P 500 Materials (Sector) (^SP500-15)
# S&P 500 Consumer Discretionary (Sector) (^SP500-25)
# S&P 500 Utilities (Sector) (^SP500-55)
# S&P 500 Consumer Staples (Sector) (^SP500-30)
# S&P 500 Telecommunication Services (Sector) (^SP500-50)

# a dictionary of sector and ticker
sector_dictionary = {
    '^SP500-45':'Technology' ,
    '^SP500-20':'Industrials',
    '^SP500-35':'Health Care',
    '^SP500-40':'Financials',
    '^SP500-60':'Real Estate',
    '^GSPE':'Energy',
    '^SP500-15':'Materials',
    '^SP500-25':'Consumer Discretionary',
    '^SP500-55':'Utilities',
    '^SP500-30':'Consumer Staples',
    '^SP500-50':'Telecommunication Services'
    }

sectors = ['^SP500-45','^SP500-20','^SP500-35','^SP500-40','^SP500-60','^GSPE','^SP500-15','^SP500-25','^SP500-55','^SP500-30','^SP500-50']
sector_data = pd.DataFrame()

for a in sectors:
    #you can chagne the start date to any date in 'yyyy-mm-dd' format.
    sector_data[a] = web.DataReader(a, data_source = 'yahoo', start = '2022-1-1')['Adj Close'] 

sector_data.rename(columns = sector_dictionary, inplace =True)
sector_data.head() #check the beginning of the data
# Out:
#             Technology  Industrials  Health Care  Financials  Real Estate  \
# Date
# 2022-01-03  3086.75000   887.590027  1627.819946  658.130005   321.630005
# 2022-01-04  3051.47998   905.630005  1605.310059  675.260010   320.399994
# 2022-01-05  2955.97998   896.950012  1593.930054  666.830017   310.089996
# 2022-01-06  2941.72998   901.010010  1574.660034  677.140015   310.399994
# 2022-01-07  2912.02002   900.750000  1567.500000  684.909973   308.700012
#
#                 Energy   Materials  Consumer Discretionary   Utilities  \
# Date
# 2022-01-03  435.829987  561.820007             1655.170044  360.290009
# 2022-01-04  450.899994  569.150024             1644.069946  359.119995
# 2022-01-05  450.570007  568.690002             1600.609985  358.950012
# 2022-01-06  460.890015  561.659973             1595.359985  355.170013
# 2022-01-07  467.579987  561.169983             1569.020020  357.850006
#
#             Consumer Staples  Telecommunication Services
# Date
# 2022-01-03        804.549988                  268.970001
# 2022-01-04        808.330017                  268.079987
# 2022-01-05        808.070007                  260.200012
# 2022-01-06        806.400024                  261.119995
# 2022-01-07        807.650024                  260.299988

# %%
sector_data.tail() #check the end of the data
# Out:
#              Technology  Industrials  Health Care  Financials  Real Estate  \
# Date
# 2022-06-22  2220.429932   729.900024  1450.410034  521.390015   251.619995
# 2022-06-23  2252.330078   726.059998  1482.550049  519.010010   256.670013
# 2022-06-24  2332.790039   751.419983  1506.719971  538.719971   261.970001
# 2022-06-27  2317.979980   749.549988  1512.599976  536.369995   261.279999
# 2022-06-28  2248.290039   740.940002  1486.339966  531.409973   257.649994
#
#                 Energy   Materials  Consumer Discretionary   Utilities  \
# Date
# 2022-06-22  559.710022  469.510010             1093.760010  336.890015
# 2022-06-23  538.750000  462.929993             1111.479980  344.799988
# 2022-06-24  547.020020  481.350006             1153.040039  350.859985
# 2022-06-27  562.239990  477.470001             1140.530029  353.690002
# 2022-06-28  577.419983  472.369995             1094.579956  352.420013
#
#             Consumer Staples  Telecommunication Services
# Date
# 2022-06-22        730.450012                  186.740005
# 2022-06-23        744.750000                  188.770004
# 2022-06-24        758.609985                  196.199997
# 2022-06-27        756.909973                  194.139999
# 2022-06-28        746.820007                  188.470001

# %%
(sector_data / sector_data.iloc[0]).plot(figsize=(12, 6)) #Plot of company performance without considering dividends
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
(sector_data.iloc[-1] - sector_data.iloc[0]) / sector_data.iloc[0] #shows returns since begining date.
# Out:
# Technology                   -0.271632
# Industrials                  -0.165223
# Health Care                  -0.086914
# Financials                   -0.192546
# Real Estate                  -0.198924
# Energy                        0.324874
# Materials                    -0.159215
# Consumer Discretionary       -0.338690
# Utilities                    -0.021844
# Consumer Staples             -0.071754
# Telecommunication Services   -0.299290
# dtype: float64
