# %%
# shows sector performance
# see details what sector entails (https://www.sofi.com/learn/content/sp-500-sectors/)

import pandas as pd
import pandas_datareader.data as web
from matplotlib import pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\liang\OneDrive\Documents\GitHub\simulate-efficient-frontier-3tickers\sector_portfolios\all_sector_performance.ipynb Cell 1' in <cell line: 4>()
#       <a href='vscode-notebook-cell:/c%3A/Users/liang/OneDrive/Documents/GitHub/simulate-efficient-frontier-3tickers/sector_portfolios/all_sector_performance.ipynb#ch0000000?line=0'>1</a> # shows sector performance
#       <a href='vscode-notebook-cell:/c%3A/Users/liang/OneDrive/Documents/GitHub/simulate-efficient-frontier-3tickers/sector_portfolios/all_sector_performance.ipynb#ch0000000?line=1'>2</a> # see details what sector entails (https://www.sofi.com/learn/content/sp-500-sectors/)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/liang/OneDrive/Documents/GitHub/simulate-efficient-frontier-3tickers/sector_portfolios/all_sector_performance.ipynb#ch0000000?line=3'>4</a> import pandas as pd
#       <a href='vscode-notebook-cell:/c%3A/Users/liang/OneDrive/Documents/GitHub/simulate-efficient-frontier-3tickers/sector_portfolios/all_sector_performance.ipynb#ch0000000?line=4'>5</a> import pandas_datareader.data as web
#       <a href='vscode-notebook-cell:/c%3A/Users/liang/OneDrive/Documents/GitHub/simulate-efficient-frontier-3tickers/sector_portfolios/all_sector_performance.ipynb#ch0000000?line=5'>6</a> from matplotlib import pyplot as plt
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# Forex (https://pandas-datareader.readthedocs.io/en/latest/remote_data.html#remote-data-tiingo)
# Alpha Vantage provides sector performances through the top-level function get_sector_performance_av.

web.get_sector_performance_av(api_key = 'EKA9MJ18TLFQY6SJ').head()
# Out:
#                  RT     1D     5D       1M       3M      YTD      1Y      3Y  \
# Utilities    -1.03%  1.03%  2.06%   -5.19%    9.03%    0.74%   9.76%  23.98%
# Health Care  -2.60%  1.38%  3.44%   -5.40%    0.50%   -7.02%   6.41%  49.33%
# Energy       -2.75%  1.14%  8.88%    4.59%   22.37%   50.33%  58.36%  34.30%
# Financials   -2.80%  2.69%  1.53%   -7.59%  -15.13%  -12.80%  -9.89%  26.47%
# Real Estate  -2.95%  1.05%  3.39%  -11.44%   -4.70%  -16.80%   3.09%  19.14%
#
#                  5Y      10Y
# Utilities    40.64%  103.21%
# Health Care  75.52%  259.96%
# Energy       27.55%   30.51%
# Financials   43.82%  196.70%
# Real Estate  39.95%      NaN

# %%
# using yahoo finance data
# S&P 500 Industrials (Sector) (^SP500-20)
# S&P 500 Information Technology (Sector) (^SP500-45)
# S&P 500 Health Care (Sector) (^SP500-35)
# S&P 500 Financials (Sector) (^SP500-40)
# S&P 500 Real Estate (Sector) (^SP500-60)
# S&P 500 Energy (Sector) (^GSPE)
# S&P 500 Materials (Sector) (^SP500-15)
# S&P 500 Consumer Discretionary (Sector) (^SP500-25)
# S&P 500 Utilities (Sector) (^SP500-55)
# S&P 500 Consumer Staples (Sector) (^SP500-30)
# S&P 500 Telecommunication Services (Sector) (^SP500-50)

# a dictionary of sector and ticker
sector_dictionary = {
    '^SP500-45':'Technology' ,
    '^SP500-20':'Industrials',
    '^SP500-35':'Health Care',
    '^SP500-40':'Financials',
    '^SP500-60':'Real Estate',
    '^GSPE':'Energy',
    '^SP500-15':'Materials',
    '^SP500-25':'Consumer Discretionary',
    '^SP500-55':'Utilities',
    '^SP500-30':'Consumer Staples',
    '^SP500-50':'Telecommunication Services'
    }

sectors = ['^SP500-45','^SP500-20','^SP500-35','^SP500-40','^SP500-60','^GSPE','^SP500-15','^SP500-25','^SP500-55','^SP500-30','^SP500-50']
sector_data = pd.DataFrame()

for a in sectors:
    #you can chagne the start date to any date in 'yyyy-mm-dd' format.
    sector_data[a] = web.DataReader(a, data_source = 'yahoo', start = '2021-1-1')['Adj Close'] 

sector_data.rename(columns = sector_dictionary, inplace =True)
sector_data.head() #check the beginning of the data
# Out:
#              Technology  Industrials  Health Care  Financials  Real Estate  \
# Date
# 2021-01-04  2250.169922   730.440002  1316.890015  483.799988   220.399994
# 2021-01-05  2265.929932   737.890015  1325.670044  485.600006   220.220001
# 2021-01-06  2225.020020   755.340027  1344.349976  506.779999   219.020004
# 2021-01-07  2283.969971   759.479980  1362.089966  514.229980   219.690002
# 2021-01-08  2301.169922   757.789978  1368.540039  513.239990   222.080002
#
#                 Energy   Materials  Consumer Discretionary   Utilities  \
# Date
# 2021-01-04  286.500000  451.040009             1287.849976  310.760010
# 2021-01-05  299.489990  461.420013             1298.650024  310.859985
# 2021-01-06  308.450012  480.269989             1305.209961  318.510010
# 2021-01-07  313.059998  484.040009             1328.670044  314.269989
# 2021-01-08  312.779999  481.579987             1352.530029  317.000000
#
#             Consumer Staples  Telecommunication Services
# Date
# 2021-01-04        688.690002                  218.580002
# 2021-01-05        688.760010                  219.169998
# 2021-01-06        688.299988                  217.720001
# 2021-01-07        686.070007                  220.770004
# 2021-01-08        689.469971                  221.320007

# %%
sector_data.tail() #check the end of the data
# Out:
#              Technology  Industrials  Health Care  Financials  Real Estate  \
# Date
# 2022-05-12  2296.189941   776.659973  1481.800049  548.799988   262.829987
# 2022-05-13  2375.290039   786.260010  1497.400024  556.309998   269.540009
# 2022-05-16  2353.699951   784.940002  1507.750000  551.979980   267.380005
# 2022-05-17  2422.229980   802.830017  1528.579956  566.840027   270.179993
# 2022-05-18  2307.389893   772.700012  1488.880005  550.979980   262.220001
#
#                 Energy   Materials  Consumer Discretionary   Utilities  \
# Date
# 2022-05-12  592.210022  509.980011             1140.550049  357.600006
# 2022-05-13  612.250000  517.799988             1187.300049  361.510010
# 2022-05-16  628.309998  516.830017             1162.170044  362.690002
# 2022-05-17  635.500000  531.630005             1193.300049  366.410004
# 2022-05-18  618.020020  514.750000             1114.569946  362.640015
#
#             Consumer Staples  Telecommunication Services
# Date
# 2022-05-12        790.760010                  194.910004
# 2022-05-13        802.000000                  199.809998
# 2022-05-16        805.640015                  198.630005
# 2022-05-17        796.359985                  202.250000
# 2022-05-18        745.549988                  195.360001

# %%
(sector_data / sector_data.iloc[0]).plot(figsize=(12, 6)) #Plot of company performance without considering dividends
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
(sector_data.iloc[-1] - sector_data.iloc[0]) / sector_data.iloc[0] #shows returns since begining date.
# Out:
# Technology                    0.025429
# Industrials                   0.057856
# Health Care                   0.130603
# Financials                    0.138859
# Real Estate                   0.189746
# Energy                        1.157138
# Materials                     0.141251
# Consumer Discretionary       -0.134550
# Utilities                     0.166946
# Consumer Staples              0.082563
# Telecommunication Services   -0.106231
# dtype: float64
