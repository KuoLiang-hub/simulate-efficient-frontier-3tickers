# %%
# shows sector performance
# see details in industrails (https://finance.yahoo.com/screener/predefined/ms_industrials/?.tsrc=fin-srch) 

import pandas as pd
import pandas_datareader.data as web
from matplotlib import pyplot as plt

# %%
# using yahoo finance data
# S&P 500 Industrials (Sector) (^SP500-20)

# a dictionary of sector and ticker
sector_dictionary = {'^SP500-20':'Industrials'}

sectors = ['^SP500-20','UPS','HON','BA','LMT']
sector_data = pd.DataFrame()

for a in sectors:
    #you can chagne the start date to any date in 'yyyy-mm-dd' format.
    sector_data[a] = web.DataReader(a, data_source = 'yahoo', start = '2021-1-1')['Adj Close'] 

sector_data.rename(columns = sector_dictionary, inplace =True)
sector_data.head() #check the beginning of the data
# Out:
#             Industrials         UPS         HON          BA         LMT
# Date
# 2021-01-04   730.440002  157.838547  202.298874  202.720001  332.227478
# 2021-01-05   737.890015  155.641525  202.795029  211.630005  336.227997
# 2021-01-06   755.340027  155.178986  206.491760  211.029999  335.495331
# 2021-01-07   759.479980  153.213226  206.832275  212.710007  330.212738
# 2021-01-08   757.789978  152.625412  204.322372  209.899994  323.995026

# %%
sector_data.tail() #check the end of the data
# Out:
#             Industrials         UPS         HON          BA         LMT
# Date
# 2022-05-10   782.849976  180.461411  193.775970  132.949997  439.130005
# 2022-05-11   775.590027  175.950134  191.040009  129.389999  440.410004
# 2022-05-12   776.659973  177.129990  192.919998  123.139999  434.589996
# 2022-05-13   786.260010  178.039993  193.529999  127.199997  435.170013
# 2022-05-16   784.940002  179.770004  193.960007  124.050003  437.549988

# %%
(sector_data / sector_data.iloc[0]).plot(figsize=(12, 6)) #Plot of company performance without considering dividends
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
(sector_data.iloc[-1] - sector_data.iloc[0]) / sector_data.iloc[0] #shows returns since begining date.
# Out:
# Industrials    0.074613
# UPS            0.138949
# HON           -0.041221
# BA            -0.388072
# LMT            0.317019
# dtype: float64
