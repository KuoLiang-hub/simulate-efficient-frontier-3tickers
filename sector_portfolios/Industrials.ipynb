# %%
# shows sector performance
# see details in industrails (https://finance.yahoo.com/screener/predefined/ms_industrials/?.tsrc=fin-srch) 

import pandas as pd
import pandas_datareader.data as web
from matplotlib import pyplot as plt

# %%
# using yahoo finance data
# S&P 500 Industrials (Sector) (^SP500-20)

# a dictionary of sector and ticker
sector_dictionary = {'^SP500-20':'Industrials'}

sectors = ['^SP500-20','UPS','HON','BA','LMT','GNRC']
sector_data = pd.DataFrame()

for a in sectors:
    #you can chagne the start date to any date in 'yyyy-mm-dd' format.
    sector_data[a] = web.DataReader(a, data_source = 'yahoo', start = '2021-1-1')['Adj Close'] 

sector_data.rename(columns = sector_dictionary, inplace =True)
sector_data.head() #check the beginning of the data
# Out:
#             Industrials         UPS         HON          BA         LMT  \
# Date
# 2021-01-04   730.440002  157.838531  202.298874  202.720001  332.227448
# 2021-01-05   737.890015  155.641510  202.795044  211.630005  336.227997
# 2021-01-06   755.340027  155.178970  206.491745  211.029999  335.495361
# 2021-01-07   759.479980  153.213242  206.832275  212.710007  330.212738
# 2021-01-08   757.789978  152.625427  204.322357  209.899994  323.995056
#
#                   GNRC
# Date
# 2021-01-04  224.559998
# 2021-01-05  227.979996
# 2021-01-06  246.289993
# 2021-01-07  254.500000
# 2021-01-08  252.500000

# %%
sector_data.tail() #check the end of the data
# Out:
#             Industrials         UPS         HON          BA         LMT  \
# Date
# 2022-05-23   769.570007  174.389999  189.580002  124.070000  433.029999
# 2022-05-24   768.630005  174.110001  189.960007  119.400002  442.779999
# 2022-05-25   773.539978  173.860001  190.440002  122.059998  447.540009
# 2022-05-26   788.969971  178.380005  193.100006  127.730003  447.989990
# 2022-05-27   805.119995  182.529999  196.350006  132.229996  450.559998
#
#                   GNRC
# Date
# 2022-05-23  230.669998
# 2022-05-24  215.630005
# 2022-05-25  231.220001
# 2022-05-26  241.240005
# 2022-05-27  256.170013

# %%
(sector_data / sector_data.iloc[0]).plot(figsize=(12, 6)) #Plot of company performance without considering dividends
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
(sector_data.iloc[-1] - sector_data.iloc[0]) / sector_data.iloc[0] #shows returns since begining date.
# Out:
# Industrials    0.102240
# UPS            0.156435
# HON           -0.029406
# BA            -0.347721
# LMT            0.356179
# GNRC           0.140764
# dtype: float64
