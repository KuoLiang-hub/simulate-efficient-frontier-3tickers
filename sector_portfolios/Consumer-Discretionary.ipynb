# %%
# shows sector performance
# see details (https://www.marketbeat.com/stocks/sectors/consumer-discretionary/)
import pandas as pd
import pandas_datareader.data as web
from matplotlib import pyplot as plt

# %%
# using yahoo finance data
# S&P 500 Consumer Discretionary (Sector) (^SP500-25)

# a dictionary of sector and ticker
sector_dictionary = {'^SP500-25':'Consumer Discretionary'}

sectors = ['^SP500-25','EBAY','FL','BBY','SBUX']
sector_data = pd.DataFrame()

for a in sectors:
    #you can chagne the start date to any date in 'yyyy-mm-dd' format.
    sector_data[a] = web.DataReader(a, data_source = 'yahoo', start = '2021-1-1')['Adj Close'] 

sector_data.rename(columns = sector_dictionary, inplace =True)
sector_data.head() #check the beginning of the data
# Out:
#             Consumer Discretionary       EBAY         FL         BBY  \
# Date
# 2021-01-04             1287.849976  50.722763  37.681442   97.095612
# 2021-01-05             1298.650024  51.244762  38.866817   97.588394
# 2021-01-06             1305.209961  52.416809  42.018177  102.332542
# 2021-01-07             1328.670044  52.259220  42.345840  104.071739
# 2021-01-08             1352.530029  53.657791  42.297657  103.936470
#
#                   SBUX
# Date
# 2021-01-04  100.205978
# 2021-01-05  100.536430
# 2021-01-06  101.265388
# 2021-01-07  100.448952
# 2021-01-08  102.703835

# %%
sector_data.tail() #check the end of the data
# Out:
#             Consumer Discretionary       EBAY         FL        BBY       SBUX
# Date
# 2022-05-18             1114.569946  44.939999  30.920000  75.620003  71.279999
# 2022-05-19             1116.010010  44.619999  30.299999  73.320000  71.930000
# 2022-05-20             1098.910034  44.310001  31.540001  72.360001  73.389999
# 2022-05-23             1105.910034  45.189999  30.660000  72.589996  73.419998
# 2022-05-24             1077.390015  44.180000  30.090000  73.470001  72.720001

# %%
(sector_data / sector_data.iloc[0]).plot(figsize=(12, 6)) #Plot of company performance without considering dividends
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
(sector_data.iloc[-1] - sector_data.iloc[0]) / sector_data.iloc[0] #shows returns since begining date.
# Out:
# Consumer Discretionary   -0.163420
# EBAY                     -0.128991
# FL                       -0.201464
# BBY                      -0.243323
# SBUX                     -0.274295
# dtype: float64
