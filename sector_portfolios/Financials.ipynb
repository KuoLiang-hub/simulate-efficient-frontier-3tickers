# %%
# shows sector performance
# see details (https://finance.yahoo.com/screener/predefined/ms_financial_services/?.tsrc=fin-srch)
import pandas as pd
import pandas_datareader.data as web
from matplotlib import pyplot as plt

# %%
# using yahoo finance data
# S&P 500 Financials (Sector) (^SP500-40)

# a dictionary of sector and ticker
sector_dictionary = {'^SP500-40':'Financials'}

sectors = ['^SP500-40','BRK-A','JPM','BAC','GS','UPST']
sector_data = pd.DataFrame()

for a in sectors:
    #you can chagne the start date to any date in 'yyyy-mm-dd' format.
    sector_data[a] = web.DataReader(a, data_source = 'yahoo', start = '2021-1-1')['Adj Close'] 

sector_data.rename(columns = sector_dictionary, inplace =True)
sector_data.head() #check the beginning of the data
# Out:
#             Financials   BRK-A         JPM        BAC          GS       UPST
# Date
# 2021-01-04  483.799988  343525  121.156876  29.319450  258.902100  43.990002
# 2021-01-05  485.600006  341820  121.816116  29.544008  264.695618  48.369999
# 2021-01-06  506.779999  346189  127.536102  31.389288  278.979187  52.139999
# 2021-01-07  514.229980  350089  131.724289  32.082489  284.938812  55.389999
# 2021-01-08  513.239990  352039  131.869720  31.760298  283.404968  52.730000

# %%
sector_data.tail() #check the end of the data
# Out:
#             Financials   BRK-A         JPM        BAC          GS       UPST
# Date
# 2022-05-23  564.159973  464510  124.599998  35.869999  316.609985  41.950001
# 2022-05-24  562.830017  463606  126.360001  35.650002  313.950012  37.150002
# 2022-05-25  567.340027  462890  127.239998  35.840000  314.899994  40.470001
# 2022-05-26  580.099976  468805  129.440002  36.669998  323.630005  43.099998
# 2022-05-27  590.460022  478670  131.270004  37.020000  328.579987  50.330002

# %%
(sector_data / sector_data.iloc[0]).plot(figsize=(12, 6)) #Plot of company performance without considering dividends
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
(sector_data.iloc[-1] - sector_data.iloc[0]) / sector_data.iloc[0] #shows returns since begining date.
# Out:
# Financials    0.220463
# BRK-A         0.393407
# JPM           0.083471
# BAC           0.262643
# GS            0.269128
# UPST          0.144124
# dtype: float64
