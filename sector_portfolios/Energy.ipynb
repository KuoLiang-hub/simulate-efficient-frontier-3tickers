# %%
# shows sector performance
# see details (https://finance.yahoo.com/screener/predefined/ms_energy/?.tsrc=fin-srch)
import pandas as pd
import pandas_datareader.data as web
from matplotlib import pyplot as plt

# %%
# using yahoo finance data
# S&P 500 Energy (Sector) (^GSPE)

# a dictionary of sector and ticker
sector_dictionary = {'^GSPE':'Energy'}

sectors = ['^GSPE','XOM','SHEL','CVX']
sector_data = pd.DataFrame()

for a in sectors:
    #you can chagne the start date to any date in 'yyyy-mm-dd' format.
    sector_data[a] = web.DataReader(a, data_source = 'yahoo', start = '2021-1-1')['Adj Close'] 

sector_data.rename(columns = sector_dictionary, inplace =True)
sector_data.head() #check the beginning of the data
# Out:
#                 Energy        XOM       SHEL        CVX
# Date
# 2021-01-04  286.500000  38.275223  34.649849  79.654846
# 2021-01-05  299.489990  40.119808  37.034847  81.808174
# 2021-01-06  308.450012  41.143555  38.746662  84.441086
# 2021-01-07  313.059998  41.466358  38.794750  84.836029
# 2021-01-08  312.779999  41.927505  38.698582  85.644699

# %%
sector_data.tail() #check the end of the data
# Out:
#                 Energy        XOM       SHEL         CVX
# Date
# 2022-05-10  583.659973  84.157944  54.939999  160.779999
# 2022-05-11  591.630005  85.910004  55.869999  163.160004
# 2022-05-12  592.210022  86.300003  55.220001  164.710007
# 2022-05-13  612.250000  88.860001  56.700001  167.869995
# 2022-05-16  628.309998  90.949997  58.060001  173.009995

# %%
(sector_data / sector_data.iloc[0]).plot(figsize=(12, 6)) #Plot of company performance without considering dividends
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
(sector_data.iloc[-1] - sector_data.iloc[0]) / sector_data.iloc[0] #shows returns since begining date.
# Out:
# Energy    1.193054
# XOM       1.376211
# SHEL      0.675621
# CVX       1.171996
# dtype: float64
