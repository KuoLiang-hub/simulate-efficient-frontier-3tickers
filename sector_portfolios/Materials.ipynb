# %%
# shows sector performance
# see details (https://finance.yahoo.com/screener/predefined/ms_basic_materials/?.tsrc=fin-srch)

import pandas as pd
import pandas_datareader.data as web
from matplotlib import pyplot as plt

# %%
# using yahoo finance data
# S&P 500 Materials (Sector) (^SP500-15)

# a dictionary of sector and ticker
sector_dictionary = {'^SP500-15':'Materials'}

sectors = ['^SP500-15','BHP','RIO','LIN']
sector_data = pd.DataFrame()

for a in sectors:
    #you can chagne the start date to any date in 'yyyy-mm-dd' format.
    sector_data[a] = web.DataReader(a, data_source = 'yahoo', start = '2021-1-1')['Adj Close'] 

sector_data.rename(columns = sector_dictionary, inplace =True)
sector_data.head() #check the beginning of the data
# Out:
#              Materials        BHP        RIO         LIN
# Date
# 2021-01-04  451.040009  67.349998  64.884972  254.059128
# 2021-01-05  461.420013  69.500000  66.452812  258.044586
# 2021-01-06  480.269989  71.709999  69.420807  266.516174
# 2021-01-07  484.040009  73.180000  72.086967  265.750488
# 2021-01-08  481.579987  73.459999  72.682236  265.436371

# %%
sector_data.tail() #check the end of the data
# Out:
#              Materials        BHP        RIO         LIN
# Date
# 2022-05-11  510.940002  62.770000  65.419998  300.450012
# 2022-05-12  509.980011  61.980000  64.419998  301.339996
# 2022-05-13  517.799988  63.540001  65.809998  308.769989
# 2022-05-16  516.830017  63.470001  66.570000  309.440002
# 2022-05-17  529.809998  65.430000  68.849998  316.779999

# %%
(sector_data / sector_data.iloc[0]).plot(figsize=(12, 6)) #Plot of company performance without considering dividends
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
(sector_data.iloc[-1] - sector_data.iloc[0]) / sector_data.iloc[0] #shows returns since begining date.
# Out:
# Materials    0.174641
# BHP         -0.028508
# RIO          0.061109
# LIN          0.246875
# dtype: float64
